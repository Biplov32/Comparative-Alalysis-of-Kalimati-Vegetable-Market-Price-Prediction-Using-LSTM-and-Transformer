# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/KalimatiTarkariDataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df.head()
# Out:
#              Commodity       Date Unit  Minimum  Maximum  Average
# 0   Tomato Big(Nepali)  6/16/2013   Kg     35.0     40.0     37.5
# 1  Tomato Small(Local)  6/16/2013   Kg     26.0     32.0     29.0
# 2           Potato Red  6/16/2013   Kg     20.0     21.0     20.5
# 3         Potato White  6/16/2013   Kg     15.0     16.0     15.5
# 4   Onion Dry (Indian)  6/16/2013   Kg     28.0     30.0     29.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280862 entries, 0 to 280861
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Commodity  280862 non-null  object
#  1   Date       280862 non-null  object
#  2   Unit       280862 non-null  object
#  3   Minimum    280862 non-null  float64
#  4   Maximum    280862 non-null  float64
#  5   Average    280862 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 12.9+ MB

# %%
# len(df['Commodity'].unique())
# c=df.Commodity.value_counts().to_dict()
# c

# %%
df.drop('Unit', axis=1, inplace=True)
df.drop('Minimum', axis=1, inplace=True)
df.drop('Maximum', axis=1, inplace=True)

# %%
desired_commodity = "Cauli Local"
df_caulilocal= df[df['Commodity'] == desired_commodity]

# %%
df_caulilocal.to_csv('/content/drive/MyDrive/Dataset/Final_Dataset/cauli_local.csv', index=False)

# %%
desired_commodity = "Ginger"
df_Ginger= df[df['Commodity'] == desired_commodity]

# %%
df_Ginger.to_csv('/content/drive/MyDrive/Dataset/Final_Dataset/Ginger.csv', index=False)

# %%
desired_commodity = "Potato Red"
df_Potato_Red= df[df['Commodity'] == desired_commodity]

# %%
df_Potato_Red.to_csv('/content/drive/MyDrive/Dataset/Final_Dataset/Potato_Red.csv', index=False)

# %%
desired_commodity = "Cabbage(Local)"
df_Cabbage_Local= df[df['Commodity'] == desired_commodity]

# %%
df_Cabbage_Local.to_csv('/content/drive/MyDrive/Dataset/Final_Dataset/Cabbage_Local.csv', index=False)

# %%
desired_commodity = "Carrot(Local)"
df_Carrot_Local= df[df['Commodity'] == desired_commodity]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1028ea424c62> in <cell line: 2>()
#       1 desired_commodity = "Carrot(Local)"
# ----> 2 df_Carrot_Local= df[df['Commodity'] == desired_commodity]
#
# NameError: name 'df' is not defined

# %%
df_Carrot_Local.to_csv('/content/drive/MyDrive/Dataset/Final_Dataset/Carrot_Local.csv', index=False)
